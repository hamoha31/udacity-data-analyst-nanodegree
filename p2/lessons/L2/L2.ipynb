# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
array = pd.Series([1,3,5,1000,6,8])
array
# Out:
# 0       1
# 1       3
# 2       5
# 3    1000
# 4       6
# 5       8
# dtype: int64

# %%
array.max()
# Out:
# 1000

# %%
array.std()
# Out:
# 406.37753382784342

# %%
array.describe()
# Out:
# count       6.000000
# mean      170.500000
# std       406.377534
# min         1.000000
# 25%         3.500000
# 50%         5.500000
# 75%         7.500000
# max      1000.000000
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
employments = pd.read_csv('employment_above_15.csv')
employments.max()
# Out:
# Country    Zimbabwe
# 1991           87.5
# 1992           87.2
# 1993             87
# 1994           87.7
# 1995           87.3
# 1996           86.8
# 1997           86.1
# 1998           85.9
# 1999           85.7
# 2000           85.1
# 2001           84.3
# 2002             84
# 2003           83.6
# 2004           83.4
# 2005           84.3
# 2006           84.1
# 2007           83.2
# dtype: object

# %%
employments
# Out:
#                     Country       1991       1992       1993       1994  \
# 0               Afghanistan  56.700001  56.500000  56.599998  56.200001
# 1                   Albania  52.700001  52.299999  52.400002  52.700001
# 2                   Algeria  39.400002  38.900002  39.400002  39.400002
# 3                    Angola  75.800003  75.800003  75.500000  75.900002
# 4                 Argentina  53.599998  53.799999  53.700001  53.799999
# 5                   Armenia  39.299999  38.200001  37.400002  37.400002
# 6                 Australia  57.200001  56.200001  55.900002  56.900002
# 7                   Austria  54.200001  54.900002  54.700001  56.400002
# 8                Azerbaijan  56.900002  56.799999  56.599998  56.200001
# 9                   Bahamas  63.000000  61.299999  62.799999  62.700001
# 10                  Bahrain  61.200001  61.400002  61.500000  61.799999
# 11               Bangladesh  74.500000  72.500000  73.000000  71.800003
# ...

# %%
employments[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-f73860ba9b43> in <module>()
# ----> 1 employments[1]
#
# C:\Users\User\Anaconda3\envs\DAND\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\User\Anaconda3\envs\DAND\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Users\User\Anaconda3\envs\DAND\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
# ...

# %%
arr = np.array([1,1,1,2])
arr
# Out:
# array([1, 1, 1, 2])

# %%
arr.max()
# Out:
# 2

# %%
arr.min()
# Out:
# 1

# %%
arr.std()
# Out:
# 0.4330127018922193

# %%
arr.mean()
# Out:
# 1.25

# %%
arr = arr + 1

# %%
arr
# Out:
# array([2, 2, 2, 3])
